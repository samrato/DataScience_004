# %% [markdown]
# BASIC STATISTICS

# %%
import pandas as pd

# %%
data=pd.read_csv('../Datasets/dataSetofHeights.csv')
data.head()
# Out:
#       Heights Gender
# 0  160.377337   Male
# 1  177.637818   Male
# 2  166.258270   Male
# 3  182.467287   Male
# 4  182.368534   Male

# %%
data.describe()
# Out:
#            Heights
# count  1000.000000
# mean    168.306355
# std       9.812907
# min     143.501854
# 25%     160.946318
# 50%     168.019906
# 75%     175.859809
# max     197.707840

# %%
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
plt.hist(data['Heights'])
# Out:
# (array([ 15.,  64., 131., 186., 191., 169., 145.,  77.,  17.,   5.]),
#  array([143.50185376, 148.92245242, 154.34305108, 159.76364974,
#         165.1842484 , 170.60484706, 176.02544572, 181.44604438,
#         186.86664304, 192.2872417 , 197.70784036]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Heights'],cumulative=True)
# Out:
# (array([  15.,   79.,  210.,  396.,  587.,  756.,  901.,  978.,  995.,
#         1000.]),
#  array([143.50185376, 148.92245242, 154.34305108, 159.76364974,
#         165.1842484 , 170.60484706, 176.02544572, 181.44604438,
#         186.86664304, 192.2872417 , 197.70784036]),
#  <BarContainer object of 10 artists>)

# %%
data.describe()
# Out:
#            Heights
# count  1000.000000
# mean    168.306355
# std       9.812907
# min     143.501854
# 25%     160.946318
# 50%     168.019906
# 75%     175.859809
# max     197.707840

# %% [markdown]
# Deviation

# %%
deviation=data['Heights']-data['Heights'].mean()

deviation
# Out:
# 0      -7.929018
# 1       9.331463
# 2      -2.048084
# 3      14.160933
# 4      14.062179
#          ...
# 995     1.775239
# 996    -8.328177
# 997   -17.637951
# 998    -4.320811
# 999    -7.895217
# Name: Heights, Length: 1000, dtype: float64

# %%
import numpy as np

# %%
meanabso=(abs(data['Heights']-data['Heights'].mean())).mean()
meanabso
# Out:
# 8.134686902556256

# %% [markdown]
# Variance

# %%
variance=((data['Heights']-data['Heights'].mean())**2).mean()
variance
# Out:
# 96.19684201398101

# %%
import math

# %%
std=math.sqrt(variance)

# %%
std
# Out:
# 9.807998879179229

# %%
data.describe()
# Out:
#            Heights
# count  1000.000000
# mean    168.306355
# std       9.812907
# min     143.501854
# 25%     160.946318
# 50%     168.019906
# 75%     175.859809
# max     197.707840

# %%
import numpy as np 
np.std(data['Heights'])
# Out:
# 9.807998879179232

# %% [markdown]
# Variance and standard deviation

# %%
#Calculation of variance and standard deviation 
var=np.var(data['Heights'])

# %%
print("variance is :",var)
# Out:
# variance is : 96.19684201398107

# %%
deviavion=np.std(data['Heights'])

# %%
print(deviavion)
# Out:
# 9.807998879179232

# %%
import math

# %%
std=math.sqrt(var)

# %%
std
# Out:
# 9.807998879179232

# %% [markdown]
# Coefficient of variation(CV)

# %%
value=[3200,5300,6700,8900,5600]

# %%
#calculating mean
mean=sum(value)/len(value)
print("Mean is :",mean)
# Out:
# Mean is : 5940.0

# %%
np.mean(value)
# Out:
# 5940.0

# %%
mean,stdev,variance=np.mean(value),np.std(value),np.var(value)
"the mean is {} std is {} variance is {}".format(mean,stdev,variance)
# Out:
# 'the mean is 5940.0 std is 1863.9742487491612 variance is 3474400.0'

# %%
# compute coefficient of variation (CV) for the `value` list (existing variables mean, stdev)
cv = (stdev / mean) * 100
cv
# Out:
# 31.380037857729988
